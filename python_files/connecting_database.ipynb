# %%
pip install psycopg2
# Out:
# Collecting psycopg2
#   Using cached psycopg2-2.9.7.tar.gz (383 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: psycopg2
#   Building wheel for psycopg2 (setup.py) ... done
#   Created wheel for psycopg2: filename=psycopg2-2.9.7-cp311-cp311-macosx_10_9_x86_64.whl size=133908 sha256=281788bd2fcad15c4b3ecde224776efc588aeb4fc7216dea9ce832bcc2f80768
#   Stored in directory: /Users/prudhviteja/Library/Caches/pip/wheels/ca/a2/1f/9f85470e2065e7a4089baa6c47cfa57a2f8f8e78e07390c5b4
# Successfully built psycopg2
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
import pandas as pd

# %%
try:
    hostname = 'database-1.cpplftm4nduo.us-east-1.rds.amazonaws.com'
    database = 'E_commerce'
    username = 'prudhvi'
    password = 'prudhvi'
    connection = psycopg2.connect(
        host=hostname,
        database=database,
        user=username,
        password=password
    )
    cursor = connection.cursor()
except Exception as e:
    print("Error connecting to the database:", e)
cursor.execute("SELECT * FROM information_schema.table_privileges;")
rows = cursor.fetchall()

cursor.close()
connection.close()


df= pd.DataFrame(rows)
df
# Out:
#             0       1           2                   3                      4  \
# 0    postgres  PUBLIC  E_commerce              public            orders_test
# 1    rdsadmin  PUBLIC  E_commerce          pg_catalog                pg_type
# 2    rdsadmin  PUBLIC  E_commerce          pg_catalog       pg_foreign_table
# 3    rdsadmin  PUBLIC  E_commerce          pg_catalog               pg_roles
# 4    rdsadmin  PUBLIC  E_commerce          pg_catalog            pg_settings
# ..        ...     ...         ...                 ...                    ...
# 184  rdsadmin  PUBLIC  E_commerce  information_schema        foreign_servers
# 185  rdsadmin  PUBLIC  E_commerce  information_schema  foreign_table_options
# 186  rdsadmin  PUBLIC  E_commerce  information_schema         foreign_tables
# 187  rdsadmin  PUBLIC  E_commerce  information_schema   user_mapping_options
# 188  rdsadmin  PUBLIC  E_commerce  information_schema          user_mappings
#
#           5   6    7
# 0    SELECT  NO  YES
# 1    SELECT  NO  YES
# 2    SELECT  NO  YES
# 3    SELECT  NO  YES
# 4    SELECT  NO  YES
# ..      ...  ..  ...
# 184  SELECT  NO  YES
# 185  SELECT  NO  YES
# 186  SELECT  NO  YES
# 187  SELECT  NO  YES
# 188  SELECT  NO  YES
#
# [189 rows x 8 columns]
